# %%
import json
import os
import shutil
from collections import defaultdict

# %%
# --- CONFIGURAÇÕES ---
# Onde estão os arquivos brutos gerados pelo scrap.ipynb
SOURCE_DIR = "json"

# Onde vamos salvar a estrutura organizada
TARGET_BASE = "data"

# Pastas de destino
DIRS = {
    "brands": os.path.join(TARGET_BASE, "brands"),
    "castings": os.path.join(TARGET_BASE, "castings"),
    "releases": os.path.join(TARGET_BASE, "releases"),
    "series": os.path.join(TARGET_BASE, "series")
}

# Cria as pastas se não existirem
for path in DIRS.values():
    os.makedirs(path, exist_ok=True)

print(f"📂 Diretórios de destino configurados em: {TARGET_BASE}")
# Out:
# 📂 Diretórios de destino configurados em: python/data
